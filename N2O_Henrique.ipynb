# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
N2O_df = pd.read_csv('C:/temp/n2o_henr.csv', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
N2O_df.plot()
N2O_df.
# Out:
#                 MR   ACI-2     ASR   ASS-2     SA
# Date
# 2014-05-21   173.2   173.2   173.2   173.2   173.2
# 2014-05-23  2365.5  5933.5  2325.6  4351.2  2816.0
# 2014-05-26   568.6  1688.2   453.3  1244.2  1038.9
# 2014-05-28  1112.7  1841.6   997.2  1410.5   764.2
# 2014-05-30   483.9  1743.3   985.9  1012.0   573.4
# 2014-06-02   816.4  1521.0  1452.0  1200.1   676.3
# 2014-06-04   243.8  1131.5   478.8   492.6   295.2
# 2014-06-06   180.7  1221.1   428.9   482.9   215.9
# 2014-06-09    70.1   681.7   435.3   448.7   173.7
# 2014-06-11     4.9   676.9   265.8   459.8   192.1
# 2014-06-13    57.9   554.8   493.1   529.8   221.4
# 2014-06-16   174.9   471.5   467.1   772.7   139.9
# 2014-06-20   150.5   354.5   722.3   258.4   325.0

# %%
N2O_df = pd.read_csv('C:/temp/fluxDelta.csv', index_col='Day')
N2O_df
# Out:
#     repetition        flux
# Day
# 1           R1   68.159597
# 1           R2   61.618590
# 1           R3   73.758261
# 1           R4   51.900755
# 2           R1   41.546259
# 2           R2   73.853485
# 2           R3   22.425538
# 2           R4   76.346270
# 3           R1   34.185702
# 3           R2   72.220362
# 3           R3   43.085285
# 3           R4   40.461692
# 4           R1   27.525991
# 4           R2   60.527995
# 4           R3   42.804554
# 4           R4   39.980087
# 5           R1         NaN
# 5           R2   53.802048
# 5           R3    9.871723
# 5           R4   72.561801
# 6           R1   30.414459
# 6           R2   45.960769
# 6           R3   43.837548
# 6           R4   69.927101
# 7           R1   45.676772
# 7           R2   62.281316
# 7           R3   65.268709
# 7           R4   21.938063
# 8           R1   49.170563
# 8           R2   37.107887
# ..         ...         ...
# 30          R3   40.443321
# 30          R4   49.234231
# ...

# %%
N2O_df['flux'].groupby('flux', by='Day', as_index=True)
#weekday_counts = berri_bikes.groupby('weekday').aggregate(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-952d521a4ddd> in <module>()
# ----> 1 N2O_df['flux'].groupby('flux', by='Day', as_index=True)
#       2 #weekday_counts = berri_bikes.groupby('weekday').aggregate(sum)
#
# TypeError: groupby() got multiple values for keyword argument 'by'

# %%
broken_df = pd.read_csv('../data/bikes.csv')
broken_df
# Out:
#     Date;Berri 1;Br�beuf (donn�es non disponibles);C�te-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (donn�es non disponibles)
# 0                     01/01/2012;35;;0;38;51;26;10;16;
# 1                     02/01/2012;83;;1;68;153;53;6;43;
# 2                   03/01/2012;135;;2;104;248;89;3;58;
# 3                  04/01/2012;144;;1;116;318;111;8;61;
# 4                  05/01/2012;197;;2;124;330;97;13;95;
# 5                    06/01/2012;146;;0;98;244;86;4;75;
# 6                     07/01/2012;98;;2;80;108;53;6;54;
# 7                     08/01/2012;95;;1;62;98;64;11;63;
# 8                09/01/2012;244;;2;165;432;198;12;173;
# 9                10/01/2012;397;;3;238;563;275;18;241;
# 10               11/01/2012;273;;0;182;443;258;12;194;
# 11                 12/01/2012;157;;1;134;261;137;9;63;
# 12                     13/01/2012;75;;0;41;105;64;2;0;
# 13                      14/01/2012;32;;0;54;56;19;0;1;
# ...

# %%
fixed_df = pd.read_csv('../data/bikes.csv', sep=';', dayfirst=False, index_col='Date')
fixed_df[:3]
# Out:
#             Berri 1  Br�beuf (donn�es non disponibles)  C�te-Sainte-Catherine  \
# Date
# 01/01/2012       35                                NaN                      0
# 02/01/2012       83                                NaN                      1
# 03/01/2012      135                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 01/01/2012             38             51       26            10       16
# 02/01/2012             68            153       53             6       43
# 03/01/2012            104            248       89             3       58
#
#             St-Urbain (donn�es non disponibles)
# Date
# 01/01/2012                                  NaN
# 02/01/2012                                  NaN
# 03/01/2012                                  NaN

# %%
fixed_df = pd.read_csv('../data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df['Berri 1'].plot()
